# %% [markdown]
# <a href="https://colab.research.google.com/github/BigDaa007/Machine-Learning-Notes/blob/main/4.Seaborn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Importing Libraries**

# %%
import pandas as pd
import seaborn as sns
import numpy as np

# %% [markdown]
# # **DataSet**

# %%
tips = sns.load_dataset('tips')

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'tips',
#  'titanic']

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.shape
# Out:
# (244, 7)

# %%
tips.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# # **Barplot**

# %%
sns.barplot(x='sex',y='total_bill',data=tips,estimator=np.std)

# %%
sns.barplot(x='sex',y='total_bill',data=tips)

# %% [markdown]
# # **Count Plot**

# %%
sns.countplot(x='sex',data=tips)

# %%
sns.countplot(x='time',data=tips)

# %% [markdown]
# # **Box Plot**

# %%
sns.boxplot(x='day',y='total_bill',data=tips)

# %%
sns.boxplot(x='day',y='total_bill',data=tips,hue='smoker')

# %%
sns.boxplot(x='day',y='total_bill',data=tips,hue='sex')

# %% [markdown]
# # **Voilin Plot**

# %%
sns.violinplot(x='day',y='total_bill',data=tips)

# %%
sns.violinplot(x='day',y='total_bill',data=tips,hue = 'sex')

# %%
sns.violinplot(x='day',y='total_bill',data=tips,hue = 'sex',split=True)

# %% [markdown]
# # **Dist Plot**

# %%
sns.distplot(tips['total_bill'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(tips['total_bill'],kde=False)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.kdeplot(tips['total_bill'])

# %% [markdown]
# # **Joint Plot**

# %%
sns.jointplot(x='total_bill',y='tip',data=tips,kind='hex')

# %%
['scatter', 'hist', 'hex', 'kde', 'reg', 'resid']

# %%
sns.jointplot(x='total_bill',y='tip',data=tips,kind='reg')

# %%
sns.jointplot(x='total_bill',y='tip',data=tips,kind='kde')

# %% [markdown]
# # **Pair Plot**

# %%
sns.pairplot(tips)

# %%
sns.pairplot(tips,hue='sex')

# %% [markdown]
# # **Correlation**
#
# *   finds correlation b/w all non categorical data

# %%
tips_corr = tips.corr()

# %%
tips_corr
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %% [markdown]
# # **Heat Map**

# %%
sns.heatmap(tips_corr,annot=True)

# %%
sns.heatmap(tips_corr,annot=True)

# %%
flights = sns.load_dataset('flights')

# %%
flights
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
flights_pivot=flights.pivot_table(index='month',columns='year',values='passengers')

# %%
sns.heatmap(flights_pivot)
