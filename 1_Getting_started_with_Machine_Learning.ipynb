# %% [markdown]
# <a href="https://colab.research.google.com/github/BigDaa007/Machine-Learning-Notes/blob/main/1_Getting_started_with_Machine_Learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#  # **Machine Learning Pipeline**

# %% [markdown]
# *   Data Generation
# *   Data Cleaning / Feature Engineering
#
# *   Algorithms to find interesting patterns
# *   Deployment

# %% [markdown]
#  ## **Data Generation**
#
#
# *   Generate own data
# *   Collect data from already available sources
# *   Web Scrapping

# %% [markdown]
#  ## **Feature Engineering**
#
#
# *   Not all features are relevant for our goal
# *   We can filter out the required data

# %% [markdown]
#  ## **Algorithms to find interesting patterns**
#
#
# *   Build models using most effective algorithm

# %% [markdown]
#  ## **Deployment**
#
#
# *   Once our model is ready we can deploy our model on web so that it can do its work

# %% [markdown]
#  # **Supervised Learning Introduction**

# %% [markdown]
# *   learn from labelled data
# *   generalise predictions on future data
# *   avoid overfitting

# %% [markdown]
#  ## **Types Of Supervised Learning**

# %% [markdown]
#  ### **Regression**
#
# *   Output is a continuous value
# *   Goal: Minimize loss(error)

# %% [markdown]
#  ### **Classification**
#
#
# *   output is a discrete value
# *   every value represents a class
# *   Goal: Minimize misclassification

# %% [markdown]
# ![Screenshot (39).png](data:image/png;base64,...)

# %% [markdown]
#  ### **Hypothesis** is a fuction having parameters
#       Eg. ax^2 + bx + c = 0 is a fuction
#       a,b,c are the parameters

# %% [markdown]
#  ### **Hyperplanes** are decision boundaries that help classify the data points. Data points falling on either side of the hyperplane can be attributed to different classes. Also, the dimension of the hyperplane depends upon the number of features. If the number of input features is 2, then the hyperplane is just a line.

# %% [markdown]
#  ### **Overfitting** happens when a model learns the detail and noise in the training data to the extent that it negatively impacts the performance of the model on new data. This means that the noise or random fluctuations in the training data is picked up and learned as concepts by the model.
#
#  [**More on this on : Geeks4Geeks**](https://www.geeksforgeeks.org/underfitting-and-overfitting-in-machine-learning/)
